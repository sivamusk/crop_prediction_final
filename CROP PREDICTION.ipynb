# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\LENOVO\Downloads\Project4_Ag_Prediction of Agriculture Crop Production In India\datafile (1).csv')
data.head()
print(data)
# Out:
#                     Crop           State  Cost_of_Cultivation1    \
# 0                  ARHAR   Uttar Pradesh                 9794.05
# 1                  ARHAR       Karnataka                10593.15
# 2                  ARHAR         Gujarat                13468.82
# 3                  ARHAR  Andhra Pradesh                17051.66
# 4                  ARHAR     Maharashtra                17130.55
# 5                 COTTON     Maharashtra                23711.44
# 6                 COTTON          Punjab                29047.10
# 7                 COTTON  Andhra Pradesh                29140.77
# 8                 COTTON         Gujarat                29616.09
# 9                 COTTON         Haryana                29918.97
# 10                  GRAM       Rajasthan                 8552.69
# 11                  GRAM  Madhya Pradesh                 9803.89
# 12                  GRAM   Uttar Pradesh                12833.04
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Crop = le.fit_transform(data.Crop)
State = le.fit_transform(data.State)
 
data['Crop'] = Crop
data['State'] = State

# %%
data.head(1)
# Out:
#    Crop  State  Cost_of_Cultivation1    Cost_of_Cultivation 2  \
# 0     0     11                 9794.05               23076.74
#
#    Cost_of_Production3  Yield
# 0              1941.55   9.83

# %%
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
X = data.iloc[:,:-1]
y = data.iloc[:,-1]
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.2,random_state=100)
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score , classification_report, mean_squared_error, r2_score
forest = RandomForestRegressor(n_estimators=1000, 
                               criterion='mse', 
                               random_state=1, 
                               n_jobs=-1)
forest.fit(X_train, Y_train)
y_train_pred = forest.predict(X_train)
y_test_pred = forest.predict(X_test)

print('MSE train: %.3f, test: %.3f' % (
        mean_squared_error(Y_train, y_train_pred),
        mean_squared_error(Y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (
        r2_score(Y_train, y_train_pred),
        r2_score(Y_test, y_test_pred)))
# Out:
# MSE train: 799.719, test: 5154.976
# R^2 train: 0.981, test: 0.955

# %%
print(forest.score(X_test,Y_test))
# Out:
# 0.9553967078024351

# %%
forest.predict(X_test)
# Out:
# array([ 83.05572,  76.137  , 106.23858,   6.00038, 748.37636,  45.96035,
#         11.91876,  38.08375, 773.31673,  34.86865])

# %%
X_test
# Out:
#     Crop  State  Cost_of_Cultivation1    Cost_of_Cultivation 2  \
# 6      1      8                29047.10               50828.83
# 20     4      1                13513.92               19857.70
# 33     6      8                25154.75               45291.24
# 28     5      0                 6684.18               13209.32
# 42     8      0                56621.16               91442.63
# 48     9      9                19119.08               29876.36
# 5      1      6                23711.44               33116.82
# 32     6     12                24731.06               33046.12
# 41     8      4                55655.44               86765.77
# 31     6      7                17478.05               25909.05
#
#     Cost_of_Production3
# 6               2003.76
# 20               404.43
# 33               669.86
# 28              2228.97
# 42               119.72
# 48               683.58
# 5               2539.47
# 32               731.25
# 41                86.53
# ...

# %%
forest.predict([[0,11,9794.05,23076.74,1941.55]])
# Out:
# array([10.13314])

# %%
Crop=input('enter crop:')
State=input('enter state:') 
Cost_of_Cultivation1=input('enter Cost of Cultivation   :')
Cost_of_Cultivation2=input('enter Cost of Cultivation  :')
Cost_of_Production3=input('enter Cost of Production  :')
out_1 = forest.predict([[float(Crop),
       float(State),
       float(Cost_of_Cultivation1),
       float(Cost_of_Cultivation2),
       float(Cost_of_Production3),
        ]])
print(out_1)
print('crop yield Production:',out_1)
# Out:
# enter crop:0
# enter state:11
# enter Cost of Cultivation   :9794.05
# enter Cost of Cultivation  :23076.74
# enter Cost of Production  :1941.55
# [10.13314]
# crop yield Production: [10.13314]

# %%
from tkinter import *
from tkinter import ttk

root = Tk()
root.title('Crop Yield   Prediction System')
root.geometry('900x700')
root.configure(background="orange")
var = StringVar()
label = Label( root, textvariable = var,font=('Times New Roman',20,'bold'),bd=20,background="orange")
var.set('Crop Yield  Prediction System')
label.grid(row=0,columnspan=6)

label_1 = ttk.Label(root, text ='Crop',font=("Times New Roman", 16),background="orange")
label_1.grid(row=11,column=0)
    
Entry_1= Entry(root)
Entry_1.grid(row=11,column=1)

label_2 = ttk.Label(root, text ='State',font=("Times New Roman", 16),background="orange")
label_2.grid(row=12,column=0)
    
Entry_2 = Entry(root)
Entry_2.grid(row=12,column=1)
    
    
label_3 = ttk.Label(root, text ='Cost_of_Cultivation1',font=("Times New Roman", 16),background="orange")
label_3.grid(row=13,column=0)
    
Entry_3 = Entry(root)
Entry_3.grid(row=13,column=1)

label_4 = ttk.Label(root, text ='Cost_of_Cultivation2',font=("Times New Roman", 16),background="orange")
label_4.grid(row=14,column=0)
    
Entry_4= Entry(root)
Entry_4.grid(row=14,column=1)

label_5 = ttk.Label(root, text ='Cost_of_Production3',font=("Times New Roman", 16),background="orange")
label_5.grid(row=15,column=0)
    
Entry_5 = Entry(root)
Entry_5.grid(row=15,column=1)

def predict():
    Crop = Entry_1.get()
    State = Entry_2.get()
    Cost_of_Cultivation1 = Entry_3.get()
    Cost_of_Cultivation2= Entry_4.get()
    Cost_of_Production3= Entry_5.get()
     
    out_1 = forest.predict([[float(Crop),
       float(State),
       float(Cost_of_Cultivation1),
       float(Cost_of_Cultivation2),
       float(Cost_of_Production3),
        ]])
    
    output.delete(0,END)
    output.insert(0,out_1)
   
        

b1 = Button(root, text = 'predict',font=("Times New Roman", 16),background="orange",command = predict)
b1.grid(row=20,column=0)
    
output = Entry(root)
output.grid(row=20,column=1)
    
root.mainloop()
